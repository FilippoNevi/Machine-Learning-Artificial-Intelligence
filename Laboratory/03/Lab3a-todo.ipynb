# %%
# !wget https://www.dropbox.com/s/1ix5o1sq1si6cl6/test-data-012.npy
# !wget https://www.dropbox.com/s/hyde9238smink5m/test-labels-012.npy
# !wget https://www.dropbox.com/s/09zzv7bobbweunc/train-data-012.npy
# !wget https://www.dropbox.com/s/818pccn7t85c7pn/train-labels-012.npy

# %%
# Esercizio: implementare il KNN per classificare ogni dato di test, calcolando l'accuratezza
# Provare diverse funzioni di distanza: euclidea, coseno e una terza a scelta
# Provare con K=1, K=3, K=7


import numpy as np

# 1. Carico in memoria il dataset

# 2. Analizzo i dati

# %%
# 1. Inizializzo i parametri
K = 1
fun = 'euclidean'

# 2. Calcolo la distanza fra tutti gli oggetti di train e gli oggetti di test
#   https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.cdist.html
from scipy.spatial.distance import cdist


# 3. Per ogni dato di test (argomento axis=0), ordino le distanze dalla più piccola alla più grande e trovo gli indici di train dei più vicini
# Attenzione: Tengo solo i primi K !!


# 4. Controllo le etichette di questi K punti: devo trovare la più frequente:
#     - Ottengo le etichette dei punti vicini
#     - Trovo l'etichetta più frequente! Utilizzo la moda!

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mode.html
from scipy import stats


# 5. Calcolo l'accuratezza


# Quale distanza e quale K porta a raggiungere l'accuratezza migliore?
